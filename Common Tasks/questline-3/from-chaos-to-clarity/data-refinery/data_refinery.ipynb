# %%
# !unzip archive.zip
# Out:
# Archive:  archive.zip
#   inflating: StudentsPerformance.csv

# %%
import pandas as pd
df = pd.read_csv('StudentsPerformance.csv')

# %%
df_clean = df.dropna().drop_duplicates()

# %%
# Check integrity
print("Missing:", df_clean.isnull().sum().sum())
print("Duplicates:", df_clean.duplicated().sum())

# Save the cleaned CSV
df_clean.to_csv('cleaned_students_performance.csv', index=False)
# Out:
# Missing: 0
# Duplicates: 0
